# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = [14, 14]
import matplotlib.pyplot as plt
from space_racer.map_generator import CircularMap
# 
import random

for i in range(9):
    plt.subplot(3,3,i+1)
    m = CircularMap(random.randint(8, 22), seed=None, width=0.2, debug=False)
    m.plot()
    plt.title(f"n={m.n}, seed={m.seed}, {m.is_valid()}")
# print(m.seed, m.n)
# print(m.start)

# %%
import gym_space_racer
import gym

env = gym.make('gym_space_racer:rocket-racer-v0')

env.reset()
env.render()
# Out:
# True
